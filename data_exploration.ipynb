# %%
import matplotlib.pyplot as plt
import medmnist
from torchvision import transforms
from medmnist import ChestMNIST

# %%
train_dataset = ChestMNIST(split='train', transform=transforms.ToTensor(), download=True)
num_images = 10

# Create subplots
fig, axes = plt.subplots(2, 5, figsize=(15, 5))
axes = axes.ravel()


for i in range(num_images):
    img, label = train_dataset[i]
    img = img.squeeze().numpy()

    label_str = ''.join(map(str, label.tolist())) 

    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f'Label: {label_str}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Using downloaded and verified file: C:\Users\sseyedka\.medmnist\chestmnist.npz

# %%
train_dataset = ChestMNIST(split='train', transform=transforms.ToTensor(), download=True)

labels = np.array([train_dataset[i][1] for i in range(len(train_dataset))])
label_sums = labels.sum(axis=0)

label_names = [f'Label {i}' for i in range(labels.shape[1])]

plt.figure(figsize=(12, 6))
plt.bar(label_names, label_sums, color='blue', alpha=0.7)
plt.ylabel("Frequency")
plt.xlabel("Labels")
plt.xticks(rotation=45)
plt.tight_layout()
plt.show()

plt.figure(figsize=(10, 6))
plt.hist(labels.sum(axis=1), bins=np.arange(labels.shape[1] + 2) - 0.5, color='green', alpha=0.7)
plt.ylabel("Frequency")
plt.xlabel("Number of Labels")
plt.xticks(range(labels.shape[1] + 1))
plt.tight_layout()
plt.show()
# Out:
# Using downloaded and verified file: C:\Users\sseyedka\.medmnist\chestmnist.npz
