# %%
import matplotlib.pyplot as plt
import medmnist
from torchvision import transforms
from medmnist import ChestMNIST  

train_dataset = ChestMNIST(split='train', transform=transforms.ToTensor(), download=True)
num_images = 5

fig, axes = plt.subplots(1, num_images, figsize=(12, 4))

for i in range(num_images):
    img, label = train_dataset[i]
    img = img.permute(1, 2, 0).numpy()
    axes[i].imshow(img, cmap='gray')
    axes[i].set_title(f'Label: {label}')
    axes[i].axis('off')

plt.tight_layout()
plt.show()
# Out:
# Downloading https://zenodo.org/records/10519652/files/chestmnist.npz?download=1 to /home/anderson_walsh/.medmnist/chestmnist.npz
# 100%|██████████| 82.8M/82.8M [00:06<00:00, 12.5MB/s]
